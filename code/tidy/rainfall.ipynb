# %% [markdown]
# <a href="https://colab.research.google.com/github/jnel41/GColab/blob/main/code/tidy/rainfall.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as df
import datetime as dt

# %% [markdown]
# **2016 Rainfall during Study**

# %%
arm0364_16 = pd.read_csv("data/raw/ppt/2016_IA0364.csv", index_col='day')
arm0364_16 = arm0364_16.loc['2016-05-16':'2016-06-30']
